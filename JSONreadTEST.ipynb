# %%
import json
import pandas as pd

# %%
testjson = pd.read_json("testjson.json")
# testjson["Defective Case"] = testjson["Defective Case"].str.split(":", 1, expand=True)
testjson
# Out:
#     JobID     ItemID CustomerID                  DateFound InspectShift  \
# 0  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
# 1  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
# 2  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
# 3  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
#
#   InspectGluer  TotalSamples  \
# 0      Gluer 5           599
# 1      Gluer 5           599
# 2      Gluer 5           599
# 3      Gluer 5           599
#
#                                       Defective Case
# 0  {'Defect Code': 'P1', 'Pieces Defective': '30'...
# 1  {'Defect Code': 'D3', 'Pieces Defective': '12'...
# 2  {'Defect Code': 'G1', 'Pieces Defective': '14'...
# 3  {'Defect Code': 'P1', 'Pieces Defective': '23'...

# %%
testjson.insert(8,'DefectCode', "")
testjson.insert(9, 'DefectiveSample', "")
testjson.insert(10, 'TotalSample', "")
testjson
# Out:
#     JobID     ItemID CustomerID                  DateFound InspectShift  \
# 0  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
# 1  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
# 2  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
# 3  420000  CPC002235   Titleist  datetime.date(2022, 8, 1)          1st
#
#   InspectGluer  TotalSamples  \
# 0      Gluer 5           599
# 1      Gluer 5           599
# 2      Gluer 5           599
# 3      Gluer 5           599
#
#                                       Defective Case DefectCode  \
# 0  {'Defect Code': 'P1', 'Pieces Defective': '30'...
# 1  {'Defect Code': 'D3', 'Pieces Defective': '12'...
# 2  {'Defect Code': 'G1', 'Pieces Defective': '14'...
# 3  {'Defect Code': 'P1', 'Pieces Defective': '23'...
#
#   DefectiveSample TotalSample
# 0
# 1
# 2
# 3

# %%
defectdict = testjson['Defective Case']
defectdict
# Out:
# 0    {'Defect Code': 'P1', 'Pieces Defective': '30'...
# 1    {'Defect Code': 'D3', 'Pieces Defective': '12'...
# 2    {'Defect Code': 'G1', 'Pieces Defective': '14'...
# 3    {'Defect Code': 'P1', 'Pieces Defective': '23'...
# Name: Defective Case, dtype: object

# %%
for i, row in testjson.iterrows():
    testjson['DefectCode'][i] = defectdict[i].get('Defect Code')
    testjson['DefectiveSample'][i] = defectdict[i].get('Pieces Defective')
    testjson['TotalSamples'][i] = defectdict[i].get('Total Pieces Sampled')
    
testjson
# Out:
# C:\Users\jcohen\AppData\Local\Temp\ipykernel_17428\1199621518.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testjson['DefectCode'][i] = defectdict[i].get('Defect Code')
# C:\Users\jcohen\AppData\Local\Temp\ipykernel_17428\1199621518.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testjson['DefectiveSample'][i] = defectdict[i].get('Pieces Defective')
# C:\Users\jcohen\AppData\Local\Temp\ipykernel_17428\1199621518.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
